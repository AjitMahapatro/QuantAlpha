# %% [markdown]
# # QuantAlpha EDA
#
# Use this notebook to inspect price distributions, rolling volatility, and correlation structure before modeling.

# %%
import pandas as pd
import yfinance as yf

tickers = ['AAPL', 'MSFT', 'NVDA', 'JPM', 'XOM']
prices = yf.download(tickers, start='2018-01-01', auto_adjust=True, progress=False)['Close']
prices.tail()
